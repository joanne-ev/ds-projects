# %%
import requests

outward_code = "PO19"

search_url = f"https://api.postcodes.io/postcodes?q={outward_code}&limit=1"
response = requests.get(search_url)
response.raise_for_status()
results = response.json().get("result") or []

results[0]
# Out:
# {'postcode': 'PO19 1AA',
#  'quality': 1,
#  'eastings': 485921,
#  'northings': 104178,
#  'country': 'England',
#  'nhs_ha': 'South East Coast',
#  'longitude': -0.781323,
#  'latitude': 50.830761,
#  'european_electoral_region': 'South East',
#  'primary_care_trust': 'West Sussex',
#  'region': 'South East',
#  'lsoa': 'Chichester 010D',
#  'msoa': 'Chichester 010',
#  'incode': '1AA',
#  'outcode': 'PO19',
#  'parliamentary_constituency': 'Chichester',
#  'parliamentary_constituency_2024': 'Chichester',
#  'admin_district': 'Chichester',
#  'parish': 'Chichester',
#  'admin_county': 'West Sussex',
#  'date_of_introduction': '198001',
#  'admin_ward': 'Chichester Central',
#  'ced': 'Chichester South',
#  'ccg': 'NHS Sussex',
#  'nuts': 'Chichester',
#  'pfa': 'Sussex',
#  'nhs_region': 'South East',
#  'ttwa': 'Chichester and Bognor Regis',
#  'national_park': 'England (non-National Park)',
#  'bua': 'Chichester',
#  'icb': 'NHS Sussex Integrated Care Board',
# ...
